# %%
pip install dask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/test')
# Out:
# Drive already mounted at /content/test; to attempt to forcibly remount, call drive.mount("/content/test", force_remount=True).

# %%
# %%time
df = pd.read_csv('test/MyDrive/data/crime.csv')
# Out:
# CPU times: user 32.5 s, sys: 7.67 s, total: 40.2 s
# Wall time: 54 s

# %%
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7721659 entries, 0 to 7721658
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
# %%time
df = pd.read_csv('test/MyDrive/data/crime.csv', nrows=1000)
# Out:
# CPU times: user 5.85 ms, sys: 135 ms, total: 141 ms
# Wall time: 147 ms

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1000 non-null   int64
#  1   Case Number           1000 non-null   object
#  2   Date                  1000 non-null   object
#  3   Block                 1000 non-null   object
#  4   IUCR                  1000 non-null   object
#  5   Primary Type          1000 non-null   object
#  6   Description           1000 non-null   object
#  7   Location Description  995 non-null    object
#  8   Arrest                1000 non-null   bool
#  9   Domestic              1000 non-null   bool
#  10  Beat                  1000 non-null   int64
#  11  District              1000 non-null   int64
#  12  Ward                  1000 non-null   int64
#  13  Community Area        1000 non-null   int64
#  14  FBI Code              1000 non-null   object
# ...

# %%
# %%time
df = pd.read_csv('test/MyDrive/data/crime.csv', skiprows=[i for i in range(1,1001)])
# Out:
# CPU times: user 29 s, sys: 2.93 s, total: 31.9 s
# Wall time: 34.3 s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7720659 entries, 0 to 7720658
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
# %%time
df = pd.read_csv('test/MyDrive/data/crime.csv',chunksize=1000)
# Out:
# CPU times: user 1.09 ms, sys: 156 ms, total: 157 ms
# Wall time: 164 ms

# %%
df

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# AttributeError: 'TextFileReader' object has no attribute 'info'

# %%
# %%time
sum_ward = 0
for i, chunk in enumerate(df):
  if i % 10000 == 0:
    print(f"{i+1}th execution")
  sum_ward += chunk['Ward'].sum()
print(sum_ward)
# Out:
# 1th execution
# 161681984.0
# CPU times: user 54.1 s, sys: 1.17 s, total: 55.3 s
# Wall time: 1min

# %%
from dask import dataframe as ddf

# %%
# %%time
ddf = ddf.read_csv('test/MyDrive/data/crime.csv', dtype={'Community Area': 'float64',
       'IUCR': 'object',
       'Ward': 'float64'})
# Out:
# CPU times: user 9.93 ms, sys: 163 ms, total: 173 ms
# Wall time: 178 ms

# %%
ddf
# Out:
# Dask DataFrame Structure:
#                    ID Case Number    Date   Block    IUCR Primary Type Description Location Description Arrest Domestic   Beat District     Ward Community Area FBI Code X Coordinate Y Coordinate   Year Updated On Latitude Longitude Location
# npartitions=28
#                 int64      object  object  object  object       object      object               object   bool     bool  int64    int64  float64        float64   object      float64      float64  int64     object  float64   float64   object
#                   ...         ...     ...     ...     ...          ...         ...                  ...    ...      ...    ...      ...      ...            ...      ...          ...          ...    ...        ...      ...       ...      ...
# ...

# %%
ddf.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 22 entries, ID to Location
# dtypes: object(10), bool(2), float64(6), int64(4)

# %%
ddf.head(10)
# Out:
#          ID Case Number                    Date                    Block  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM          043XX S WOOD ST
# 1  10224739    HY411615  09/04/2015 11:30:00 AM      008XX N CENTRAL AVE
# 2  11646166    JC213529  09/01/2018 12:01:00 AM    082XX S INGLESIDE AVE
# 3  10224740    HY411595  09/05/2015 12:45:00 PM        035XX W BARRY AVE
# 4  10224741    HY411610  09/05/2015 01:00:00 PM      0000X N LARAMIE AVE
# 5  10224742    HY411435  09/05/2015 10:55:00 AM      082XX S LOOMIS BLVD
# 6  10224743    HY411629  09/04/2015 06:00:00 PM     021XX W CHURCHILL ST
# 7  10224744    HY411605  09/05/2015 01:00:00 PM        025XX W CERMAK RD
# 8  10224745    HY411654  09/05/2015 11:30:00 AM  031XX W WASHINGTON BLVD
# 9  11645836    JC212333  05/01/2016 12:25:00 AM      055XX S ROCKWELL ST
#
#    IUCR        Primary Type                          Description  \
# 0  0486             BATTERY              DOMESTIC BATTERY SIMPLE
# ...

# %%
# %%time
ddf_sum = ddf['Ward'].sum().compute()
# Out:
# CPU times: user 43.1 s, sys: 2.82 s, total: 45.9 s
# Wall time: 32.7 s

# %%
ddf_sum
# Out:
# 161681984.0

# %%
ddf['Ward'].sum().compute()
# Out:
# 161681984.0
